# %% [markdown]
# # Import packages and load data

# %%
import pandas as pd
import numpy as np
import math

from NetworkClass import NetworkClass

# %% [markdown]
# # Load data and assign them to network class

# %%
df = pd.read_csv('raw/Edges.csv',index_col=0)
df
# Out:
#          lang_1      lang_2  weight
# 0       English      German    3885
# 1       English      French    4702
# 2       English       Dutch    2686
# 3       English     Russian    2050
# 4       English     Spanish    2866
# ..          ...         ...     ...
# 185     Catalan  Indonesian      10
# 186     Catalan      Korean       7
# 187     Serbian  Indonesian       4
# 188     Serbian      Korean       2
# 189  Indonesian      Korean      36
#
# [190 rows x 3 columns]

# %%
network = NetworkClass(data = df,node_col='lang_1',neighbor_col='lang_2',edge_weight_col='weight',drop_edges_viz=100)

# %% [markdown]
# # Add node size

# %%
df_size = pd.read_csv('raw/Node sizes.csv',index_col=0).head(20).rename(columns={'Language':'id','Articles':'size'})[['id','size']]
df_size = df_size.set_index('id')
df_size['size'] = df_size['size'].apply(lambda x: np.sqrt(x)/8)
df_size
# Out:
#                        size
# id
# English          322.877129
# German           209.556600
# French           198.835909
# Dutch            182.216947
# Russian          173.343139
# Spanish          171.000046
# Italian          168.417543
# Egyptian Arabic  158.997396
# Polish           156.696512
# Japanese         146.716350
# Chinese          145.893583
# Vietnamese       141.663223
# Ukrainian        140.809324
# Arabic           137.430323
# Portuguese       131.310224
# Persian          122.850328
# Catalan          106.784172
# Serbian          102.450827
# Indonesian       100.924090
# Korean            99.845271

# %%
network.add_node_attr(data=df_size,attr_name='size')

# %% [markdown]
# # Add flags and show network

# %%
for node in network.nt.nodes:
    id = node['id']
    label = node['label']
    node['shape'] = 'circularImage'
    #node['image'] = "https://www.w3schools.com/w3css/img_lights.jpg"
    node['image'] = f"/Users/federico.bindi/Desktop/GitHub/wiki-language-project/flags/{id}.png"

# %%
network.nt.nodes
# Out:
# [{'color': '#ACACAC',
#   'size': 322.87712929998617,
#   'id': 'English',
#   'label': 'English',
#   'shape': 'circularImage',
#   'font': {'color': 'white'},
#   'image': '/Users/federico.bindi/Desktop/GitHub/wiki-language-project/flags/English.png'},
#  {'color': '#ACACAC',
#   'size': 209.55660034940442,
#   'id': 'German',
#   'label': 'German',
#   'shape': 'circularImage',
#   'font': {'color': 'white'},
#   'image': '/Users/federico.bindi/Desktop/GitHub/wiki-language-project/flags/German.png'},
#  {'color': '#ACACAC',
#   'size': 198.83590910597613,
#   'id': 'French',
#   'label': 'French',
#   'shape': 'circularImage',
#   'font': {'color': 'white'},
#   'image': '/Users/federico.bindi/Desktop/GitHub/wiki-language-project/flags/French.png'},
#  {'color': '#ACACAC',
#   'size': 182.21694659114448,
#   'id': 'Dutch',
#   'label': 'Dutch',
#   'shape': 'circularImage',
#   'font': {'color': 'white'},
#   'image': '/Users/federico.bindi/Desktop/GitHub/wiki-language-project/flags/Dutch.png'},
#  {'color': '#ACACAC',
#   'size': 173.34313874509138,
#   'id': 'Russian',
#   'label': 'Russian',
#   'shape': 'circularImage',
#   'font': {'color': 'white'},
#   'image': '/Users/federico.bindi/Desktop/GitHub/wiki-language-project/flags/Russian.png'},
#  {'color': '#ACACAC',
#   'size': 171.0000456871284,
#   'id': 'Spanish',
#   'label': 'Spanish',
#   'shape': 'circularImage',
#   'font': {'color': 'white'},
#   'image': '/Users/federico.bindi/Desktop/GitHub/wiki-language-project/flags/Spanish.png'},
#  {'color': '#ACACAC',
#   'size': 168.41754288078187,
#   'id': 'Italian',
#   'label': 'Italian',
#   'shape': 'circularImage',
#   'font': {'color': 'white'},
#   'image': '/Users/federico.bindi/Desktop/GitHub/wiki-language-project/flags/Italian.png'},
#  {'color': '#ACACAC',
#   'size': 158.99739581200694,
#   'id': 'Egyptian Arabic',
#   'label': 'Egyptian Arabic',
#   'shape': 'circularImage',
#   'font': {'color': 'white'},
#   'image': '/Users/federico.bindi/Desktop/GitHub/wiki-language-project/flags/Egyptian Arabic.png'},
#  {'color': '#ACACAC',
#   'size': 156.6965120064898,
#   'id': 'Polish',
#   'label': 'Polish',
#   'shape': 'circularImage',
#   'font': {'color': 'white'},
#   'image': '/Users/federico.bindi/Desktop/GitHub/wiki-language-project/flags/Polish.png'},
#  {'color': '#ACACAC',
#   'size': 146.71635048623585,
#   'id': 'Japanese',
#   'label': 'Japanese',
#   'shape': 'circularImage',
#   'font': {'color': 'white'},
#   'image': '/Users/federico.bindi/Desktop/GitHub/wiki-language-project/flags/Japanese.png'},
#  {'color': '#ACACAC',
#   'size': 145.89358279239016,
#   'id': 'Chinese',
#   'label': 'Chinese',
#   'shape': 'circularImage',
#   'font': {'color': 'white'},
#   'image': '/Users/federico.bindi/Desktop/GitHub/wiki-language-project/flags/Chinese.png'},
#  {'color': '#ACACAC',
#   'size': 141.6632229973609,
#   'id': 'Vietnamese',
#   'label': 'Vietnamese',
#   'shape': 'circularImage',
#   'font': {'color': 'white'},
#   'image': '/Users/federico.bindi/Desktop/GitHub/wiki-language-project/flags/Vietnamese.png'},
#  {'color': '#ACACAC',
#   'size': 140.8093236437133,
#   'id': 'Ukrainian',
#   'label': 'Ukrainian',
#   'shape': 'circularImage',
#   'font': {'color': 'white'},
#   'image': '/Users/federico.bindi/Desktop/GitHub/wiki-language-project/flags/Ukrainian.png'},
#  {'color': '#ACACAC',
#   'size': 137.43032325509535,
#   'id': 'Arabic',
#   'label': 'Arabic',
#   'shape': 'circularImage',
#   'font': {'color': 'white'},
#   'image': '/Users/federico.bindi/Desktop/GitHub/wiki-language-project/flags/Arabic.png'},
#  {'color': '#ACACAC',
#   'size': 131.31022427823356,
#   'id': 'Portuguese',
#   'label': 'Portuguese',
#   'shape': 'circularImage',
#   'font': {'color': 'white'},
#   'image': '/Users/federico.bindi/Desktop/GitHub/wiki-language-project/flags/Portuguese.png'},
#  {'color': '#ACACAC',
#   'size': 122.8503281436399,
#   'id': 'Persian',
#   'label': 'Persian',
#   'shape': 'circularImage',
#   'font': {'color': 'white'},
#   'image': '/Users/federico.bindi/Desktop/GitHub/wiki-language-project/flags/Persian.png'},
#  {'color': '#ACACAC',
#   'size': 106.78417193104978,
#   'id': 'Catalan',
#   'label': 'Catalan',
#   'shape': 'circularImage',
#   'font': {'color': 'white'},
#   'image': '/Users/federico.bindi/Desktop/GitHub/wiki-language-project/flags/Catalan.png'},
#  {'color': '#ACACAC',
#   'size': 102.450826619408,
#   'id': 'Serbian',
#   'label': 'Serbian',
#   'shape': 'circularImage',
#   'font': {'color': 'white'},
#   'image': '/Users/federico.bindi/Desktop/GitHub/wiki-language-project/flags/Serbian.png'},
#  {'color': '#ACACAC',
#   'size': 100.92408966644187,
#   'id': 'Indonesian',
#   'label': 'Indonesian',
#   'shape': 'circularImage',
#   'font': {'color': 'white'},
#   'image': '/Users/federico.bindi/Desktop/GitHub/wiki-language-project/flags/Indonesian.png'},
#  {'color': '#ACACAC',
#   'size': 99.84527091955833,
#   'id': 'Korean',
#   'label': 'Korean',
#   'shape': 'circularImage',
#   'font': {'color': 'white'},
#   'image': '/Users/federico.bindi/Desktop/GitHub/wiki-language-project/flags/Korean.png'}]

# %%
network.show_network('out/network.html')
# Out:
# out/network.html
